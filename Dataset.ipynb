# %% [markdown]
# <a href="https://colab.research.google.com/github/Nainika2006/LViT-Language-Meets-Vision-Transformer-in-Medical-Image-Segmentation/blob/main/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/HUANGLIZI/LViT
# Out:
# Cloning into 'LViT'...
# remote: Enumerating objects: 323, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 323 (delta 65), reused 61 (delta 61), pack-reused 253 (from 1)
# Receiving objects: 100% (323/323), 92.10 MiB | 25.37 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
# %cd LViT
# Out:
# /content/LViT

# %%
# !pip install -r requirements.txt --no-deps
# !pip install transformers torch torchvision \
           tensorboardX thop ml-collections torchinfo
# Out:
# ...
#   Using cached absl_py-0.13.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached albumentations-0.5.2-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached bert_embedding-1.0.1-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached certifi-2021.5.30-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl.metadata (722 bytes)
# ...
#   Using cached einops-0.3.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached entmax-1.0.tar.gz (7.2 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached h5py-3.3.0.tar.gz (380 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install backend dependencies did not run successfully.
# ...

# %%
# !python train_model.py
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:   [Train] Epoch: [97][12/12]  Loss:0.163 (Avg 0.2028) IoU:0.742 (Avg 0.7013) Dice:0.8508 (Avg 0.8235) LR 4.11e-04   (AvgTime 0.4)
#    [Train] Epoch: [97][12/12]  Loss:0.163 (Avg 0.2028) IoU:0.742 (Avg 0.7013) Dice:0.8508 (Avg 0.8235) LR 4.11e-04   (AvgTime 0.4)
# INFO:root:Validation
# Validation
# INFO:root:   [Val] Epoch: [97][1/3]  Loss:0.224 (Avg 0.2240) IoU:0.698 (Avg 0.6982) Dice:0.8220 (Avg 0.8220) (AvgTime 1.0)
#    [Val] Epoch: [97][1/3]  Loss:0.224 (Avg 0.2240) IoU:0.698 (Avg 0.6982) Dice:0.8220 (Avg 0.8220) (AvgTime 1.0)
# INFO:root:   [Val] Epoch: [97][2/3]  Loss:0.230 (Avg 0.2270) IoU:0.629 (Avg 0.6637) Dice:0.7724 (Avg 0.7972) (AvgTime 0.5)
#    [Val] Epoch: [97][2/3]  Loss:0.230 (Avg 0.2270) IoU:0.629 (Avg 0.6637) Dice:0.7724 (Avg 0.7972) (AvgTime 0.5)
# INFO:root:   [Val] Epoch: [97][3/3]  Loss:0.333 (Avg 0.2624) IoU:0.573 (Avg 0.6333) Dice:0.7214 (Avg 0.7719) (AvgTime 0.4)
# ...

# %%
# !python test_model.py
# Out:
# 2025-09-04 04:59:22.938608: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756961963.034296   21827 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756961963.064455   21827 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756961963.130658   21827 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
